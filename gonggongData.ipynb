# %%
import os
import sys
import urllib.request
import datetime
import time
import json
import pandas as pd

ServiceKey="출입국관광통계서비스 API 인증키"

# %%
#[CODE 1]
def getRequestUrl(url):    
    req = urllib.request.Request(url)    
    try: 
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

# %%
    #[CODE 2]
    def getTourismStatsItem(yyyymm, national_code, ed_cd):    
        service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
        parameters = "?_type=json&serviceKey=" + ServiceKey   #인증키
        parameters += "&YM=" + yyyymm
        parameters += "&NAT_CD=" + national_code
        parameters += "&ED_CD=" + ed_cd

        url = service_url + parameters
        print(url)  #엑세스 거부 여부 확인용
        responseDecode = getRequestUrl(url)   #[CODE 1]

        if (responseDecode == None):
            return None
        else:
             return json.loads(responseDecode)

# %%
#[CODE 3]
def getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear):
    jsonResult = []
    result = []
    natName=''
    dataEND = "{0}{1:0>2}".format(str(nEndYear), str(12))  #데이터 끝 초기화
    isDataEnd = 0  #데이터 끝 확인용 flag 초기화    
    
    for year in range(nStartYear, nEndYear+1):        
        for month in range(1, 13):
            if(isDataEnd == 1): break  #데이터 끝 flag 설정되어있으면 작업 중지.
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))            
            jsonData = getTourismStatsItem(yyyymm, nat_cd, ed_cd) #[CODE 2]
            
            if (jsonData['response']['header']['resultMsg'] == 'OK'):               
                # 입력된 범위까지 수집하지 않았지만, 더이상 제공되는 데이터가 없는 마지막 항목인 경우 -------------------
                if jsonData['response']['body']['items'] == '': 
                    isDataEnd = 1 #데이터 끝 flag 설정
                    dataEND = "{0}{1:0>2}".format(str(year), str(month-1))
                    print("데이터 없음.... \n 제공되는 통계 데이터는 %s년 %s월까지입니다." %(str(year), str(month-1)))                    
                    break                
                #jsonData를 출력하여 확인......................................................
                print (json.dumps(jsonData, indent=4,sort_keys=True, ensure_ascii=False))          
                natName = jsonData['response']['body']['items']['item']['natKorNm']
                natName = natName.replace(' ', '')
                num = jsonData['response']['body']['items']['item']['num']
                ed = jsonData['response']['body']['items']['item']['ed']
                print('[ %s_%s : %s ]' %(natName, yyyymm, num))
                print('----------------------------------------------------------------------')                
                jsonResult.append({'nat_name': natName, 'nat_cd': nat_cd,
                                 'yyyymm': yyyymm, 'visit_cnt': num})
                result.append([natName, nat_cd, yyyymm, num])
                
    return (jsonResult, result, natName, ed, dataEND)

# %%
#[CODE 0]
def main():
    jsonResult = []
    result = []
    natName=''
    print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
    nat_cd = input('국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ')
    nStartYear =int(input('데이터를 몇 년부터 수집할까요? : '))
    nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
    ed_cd = "E"     #E : 방한외래관광객, D : 해외 출국
    
    jsonResult, result, natName, ed, dataEND =getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear) #[CODE 3]

    if (natName=='') : #URL 요청은 성공하였지만, 데이터 제공이 안된 경우
        print('데이터가 전달되지 않았습니다. 공공데이터포털의 서비스 상태를 확인하기 바랍니다.')
    else:
        #파일저장 1 : json 파일       
        with open('./%s_%s_%d_%s.json' % (natName, ed, nStartYear, dataEND), 'w', 
                    encoding='utf8') as outfile:
            jsonFile  = json.dumps(jsonResult, indent=4, sort_keys=True, ensure_ascii=False)
            outfile.write(jsonFile)
        #파일저장 2 : csv 파일   
        columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
        result_df = pd.DataFrame(result, columns = columns)
        result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND),
                    index=False, encoding='cp949')

# %%
if __name__ == '__main__':
    main()
# Out:
# << 국내 입국한 외국인의 통계 데이터를 수집합니다. >>
# 국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : 130
# 데이터를 몇 년부터 수집할까요? : 2018
# 데이터를 몇 년까지 수집할까요? : 2022
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201801&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.818987] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 167083,
#                     "rnum": 1,
#                     "ym": 201801
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201801 : 167083 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201802&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.847163] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 168241,
#                     "rnum": 1,
#                     "ym": 201802
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201802 : 168241 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201803&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.873796] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 294476,
#                     "rnum": 1,
#                     "ym": 201803
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201803 : 294476 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201804&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.898190] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 213853,
#                     "rnum": 1,
#                     "ym": 201804
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201804 : 213853 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201805&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.920605] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 227230,
#                     "rnum": 1,
#                     "ym": 201805
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201805 : 227230 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201806&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.949492] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 235293,
#                     "rnum": 1,
#                     "ym": 201806
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201806 : 235293 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201807&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:45.974404] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 230512,
#                     "rnum": 1,
#                     "ym": 201807
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201807 : 230512 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201808&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.005584] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 315025,
#                     "rnum": 1,
#                     "ym": 201808
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201808 : 315025 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201809&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.031791] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 247847,
#                     "rnum": 1,
#                     "ym": 201809
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201809 : 247847 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201810&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.054684] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 290468,
#                     "rnum": 1,
#                     "ym": 201810
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201810 : 290468 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201811&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.080627] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 299978,
#                     "rnum": 1,
#                     "ym": 201811
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201811 : 299978 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201812&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.108212] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 258521,
#                     "rnum": 1,
#                     "ym": 201812
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201812 : 258521 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201901&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.132241] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 206526,
#                     "rnum": 1,
#                     "ym": 201901
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201901 : 206526 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201902&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.157863] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 213200,
#                     "rnum": 1,
#                     "ym": 201902
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201902 : 213200 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201903&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.180341] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 375119,
#                     "rnum": 1,
#                     "ym": 201903
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201903 : 375119 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201904&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.203599] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 290092,
#                     "rnum": 1,
#                     "ym": 201904
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201904 : 290092 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201905&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.227166] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 286273,
#                     "rnum": 1,
#                     "ym": 201905
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201905 : 286273 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201906&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.251982] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 282476,
#                     "rnum": 1,
#                     "ym": 201906
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201906 : 282476 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201907&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.275489] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 274830,
#                     "rnum": 1,
#                     "ym": 201907
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201907 : 274830 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201908&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.298262] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 329652,
#                     "rnum": 1,
#                     "ym": 201908
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201908 : 329652 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201909&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.322457] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 251119,
#                     "rnum": 1,
#                     "ym": 201909
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201909 : 251119 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201910&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.346304] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 248541,
#                     "rnum": 1,
#                     "ym": 201910
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201910 : 248541 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201911&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.376488] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 258522,
#                     "rnum": 1,
#                     "ym": 201911
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201911 : 258522 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=201912&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.401653] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 255356,
#                     "rnum": 1,
#                     "ym": 201912
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201912 : 255356 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202001&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.426748] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 203969,
#                     "rnum": 1,
#                     "ym": 202001
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202001 : 203969 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202002&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.450851] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 211199,
#                     "rnum": 1,
#                     "ym": 202002
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202002 : 211199 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202003&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.477948] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 8347,
#                     "rnum": 1,
#                     "ym": 202003
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202003 : 8347 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202004&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.503173] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 360,
#                     "rnum": 1,
#                     "ym": 202004
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202004 : 360 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202005&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.530355] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 413,
#                     "rnum": 1,
#                     "ym": 202005
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202005 : 413 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202006&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.554966] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 498,
#                     "rnum": 1,
#                     "ym": 202006
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202006 : 498 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202007&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.577776] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 755,
#                     "rnum": 1,
#                     "ym": 202007
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202007 : 755 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202008&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.601995] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1275,
#                     "rnum": 1,
#                     "ym": 202008
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202008 : 1275 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202009&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.628420] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 794,
#                     "rnum": 1,
#                     "ym": 202009
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202009 : 794 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202010&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.654507] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 927,
#                     "rnum": 1,
#                     "ym": 202010
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202010 : 927 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202011&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.678591] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1254,
#                     "rnum": 1,
#                     "ym": 202011
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202011 : 1254 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202012&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.699203] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 951,
#                     "rnum": 1,
#                     "ym": 202012
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202012 : 951 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202101&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.722976] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1299,
#                     "rnum": 1,
#                     "ym": 202101
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202101 : 1299 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202102&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.746293] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1719,
#                     "rnum": 1,
#                     "ym": 202102
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202102 : 1719 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202103&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.767581] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 949,
#                     "rnum": 1,
#                     "ym": 202103
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202103 : 949 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202104&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.792455] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 872,
#                     "rnum": 1,
#                     "ym": 202104
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202104 : 872 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202105&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.814486] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1403,
#                     "rnum": 1,
#                     "ym": 202105
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202105 : 1403 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202106&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.835100] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 875,
#                     "rnum": 1,
#                     "ym": 202106
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202106 : 875 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202107&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.858693] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 881,
#                     "rnum": 1,
#                     "ym": 202107
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202107 : 881 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202108&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.883960] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 2258,
#                     "rnum": 1,
#                     "ym": 202108
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202108 : 2258 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202109&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.910773] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1142,
#                     "rnum": 1,
#                     "ym": 202109
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202109 : 1142 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202110&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.935757] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1237,
#                     "rnum": 1,
#                     "ym": 202110
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202110 : 1237 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202111&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.960387] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1623,
#                     "rnum": 1,
#                     "ym": 202111
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202111 : 1623 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202112&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:46.982236] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1007,
#                     "rnum": 1,
#                     "ym": 202112
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202112 : 1007 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202201&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:47.011501] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1162,
#                     "rnum": 1,
#                     "ym": 202201
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202201 : 1162 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202202&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:47.038818] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 2934,
#                     "rnum": 1,
#                     "ym": 202202
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202202 : 2934 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202203&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:47.063089] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1397,
#                     "rnum": 1,
#                     "ym": 202203
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202203 : 1397 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=4EejPwcHhBAZ7EDNRFQraaglQ65roW%2BI1IF%2BjGvqNbPnvnm97llR%2BE%2BJ%2BozG31oUgzaH7LRKQ%2BN9Y%2B7lHaUzAA%3D%3D&YM=202204&NAT_CD=130&ED_CD=E
# [2022-05-10 18:46:47.091243] Url Request Success
# 데이터 없음....
#  제공되는 통계 데이터는 2022년 3월까지입니다.

# %% [markdown]
# ##
